# %% [markdown]
# ## Predicting dog label and recomendation of similar dogs

# %%
from prediction import predict_dog_label
# Out:
# Using TensorFlow backend.

# %%
predict_dog_label()
# Out:
# Enter img url :https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/adorable-cavalier-king-charles-spaniel-puppy-royalty-free-image-523255012-1565106446.jpg?crop=0.448xw:1.00xh;0.370xw,0&resize=480:*
# 1/1 [==============================] - 3s 3s/step
# Do you want the most similar pic in database: (y/n) y
#
#  Most similar pic in database:
# Top 5 visually most similar dogs: ['papillon', 'Welsh_springer_spaniel', 'Japanese_spaniel', 'cocker_spaniel', 'Shih-Tzu']
#
# Do you want to see those dogs?: (y/n) y
# Do you want to see the features of your dog? (y,n) y
#                   Energy level  Exercise requirements  Playfulness  \
# label_name
# Blenheim_spaniel             1                      1            3
#
#                   Affection level  Friend to dogs  Friend to other pets  \
# label_name
# Blenheim_spaniel                2               4                     4
#
#                   Friend to strangers  Watchfulness  Easy training  Grooming  \
# label_name
# ...
